# %% [markdown]
# ## TBL upto Re_theta=1070, Pr=6 ##
# ### Statistics dictionary preparation ###
#
# 1. How to load the statistics file?
# x = np.load('TBL_statistics.npz')
#
# General key naming convention:\
# {quantity : flow / scalar}\
# {flow_type : fixed here (redundant) - tbl}\
# {Momentum Re : 420 / 628 / 830 / 1070} # Only 4 locations are provided. For other locations, a request shall be made\
# {Data : mean / rms / skewness / flatness / mean_params / xx_budget}\
# {Variable : u / v / w / p / s1 / s2 / s3 / s4 / us1 / ...} # For mean_params : { cf_wrt_x / cf_wrt_Rex / Redisp_wrt_x / Retheta_wrt_x / Retau_wrt_x / h12_wrt_x / h12_wrt_Retheta} is possible\
# {Scaling : outer / inner}
#
# So, to load u-RMS plot in inner-scale at Re_theta = 628,\
# urms = x\['flow_tbl_628_rms_u_inner'\]
#
# 2. How to plot the required data?\
# First, load the required data as above.\
# Then, plot it as:\
# plt.plot(urms\[0\],urms\[1\])
#
# 3. For list of keys available,\
# for i in x.keys():\
#   print(i)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.loadtxt('u_mean.m')
b = np.loadtxt('u_mean_inner.m')
c = np.loadtxt('v_mean.m')
d = np.loadtxt('v_mean_inner.m')
e = np.loadtxt('w_mean.m')
f = np.loadtxt('w_mean_inner.m')
g = np.loadtxt('p_mean.m')
h = np.loadtxt('p_mean_inner.m')

ar = np.loadtxt('urms.m')
br = np.loadtxt('urms_inner.m')
cr = np.loadtxt('vrms.m')
dr = np.loadtxt('vrms_inner.m')
er = np.loadtxt('wrms.m')
fr = np.loadtxt('wrms_inner.m')
gr = np.loadtxt('prms.m')
hr = np.loadtxt('prms_inner.m')

# %%
s1 = np.loadtxt('s1_mean.m')
s1i = np.loadtxt('s1_mean_inner.m')
s2 = np.loadtxt('s2_mean.m')
s2i = np.loadtxt('s2_mean_inner.m')
s3 = np.loadtxt('s3_mean.m')
s3i = np.loadtxt('s3_mean_inner.m')
s4 = np.loadtxt('s4_mean.m')
s4i = np.loadtxt('s4_mean_inner.m')

s1r = np.loadtxt('s1rms.m')
s1ir = np.loadtxt('s1rms_inner.m')
s2r = np.loadtxt('s2rms.m')
s2ir = np.loadtxt('s2rms_inner.m')
s3r = np.loadtxt('s3rms.m')
s3ir = np.loadtxt('s3rms_inner.m')
s4r = np.loadtxt('s4rms.m')
s4ir = np.loadtxt('s4rms_inner.m')

s1prt = np.loadtxt('s1tpr.m')
s2prt = np.loadtxt('s2tpr.m')
s3prt = np.loadtxt('s3tpr.m')
s4prt = np.loadtxt('s4tpr.m')

uv = np.loadtxt('uv.m')
us1 = np.loadtxt('us1.m')
us2 = np.loadtxt('us2.m')
us3 = np.loadtxt('us3.m')
us4 = np.loadtxt('us4.m')
vs1 = np.loadtxt('vs1.m')
vs2 = np.loadtxt('vs2.m')
vs3 = np.loadtxt('vs3.m')
vs4 = np.loadtxt('vs4.m')

uskew = np.loadtxt('uskew.m')
vskew = np.loadtxt('vskew.m')
wskew = np.loadtxt('wskew.m')
pskew = np.loadtxt('pskew.m')

uflat = np.loadtxt('uflat.m')
vflat = np.loadtxt('vflat.m')
wflat = np.loadtxt('wflat.m')
pflat = np.loadtxt('pflat.m')

cfx = np.loadtxt('cf_x.m')
cfre = np.loadtxt('cf_rex.m')
redispmom = np.loadtxt('redispmom_x.m')
retau = np.loadtxt('retau_x.m')
h12x = np.loadtxt('h12_x.m')
h12rt = np.loadtxt('h12_retheta.m')

# %%
datContent = [i.strip().split() for i in open(f"budget/u_convection.m").readlines()]
data = np.array(datContent)
u_conv = data.astype(np.float)
uu_1 = [u_conv[:,0],u_conv[:,5]]

datContent = [i.strip().split() for i in open(f"budget/u_dissipation.m").readlines()]
data = np.array(datContent)
u_diss = data.astype(np.float)
uu_2 = [u_diss[:,0],u_diss[:,5]]

datContent = [i.strip().split() for i in open(f"budget/u_mol_diff.m").readlines()]
data = np.array(datContent)
u_mol_diff = data.astype(np.float)
uu_3 = [u_mol_diff[:,0],u_mol_diff[:,5]]

datContent = [i.strip().split() for i in open(f"budget/u_prod.m").readlines()]
data = np.array(datContent)
u_prod = data.astype(np.float)
uu_4 = [u_prod[:,0],u_prod[:,5]]

datContent = [i.strip().split() for i in open(f"budget/u_turb_diff.m").readlines()]
data = np.array(datContent)
u_turb_diff = data.astype(np.float)
uu_5 = [u_turb_diff[:,0],u_turb_diff[:,5]]

datContent = [i.strip().split() for i in open(f"budget/u_vpgrad.m").readlines()]
data = np.array(datContent)
u_vpgrad = data.astype(np.float)
uu_6 = [u_vpgrad[:,0],u_vpgrad[:,5]]

datContent = [i.strip().split() for i in open(f"budget/2_convection.m").readlines()]
data = np.array(datContent)
u_conv = data.astype(np.float)
vv_1 = [u_conv[:,0],u_conv[:,5]]

datContent = [i.strip().split() for i in open(f"budget/2_diss.m").readlines()]
data = np.array(datContent)
u_diss = data.astype(np.float)
vv_2 = [u_diss[:,0],u_diss[:,5]]

datContent = [i.strip().split() for i in open(f"budget/2_mol_diff.m").readlines()]
data = np.array(datContent)
u_mol_diff = data.astype(np.float)
vv_3 = [u_mol_diff[:,0],u_mol_diff[:,5]]

datContent = [i.strip().split() for i in open(f"budget/2_prod.m").readlines()]
data = np.array(datContent)
u_prod = data.astype(np.float)
vv_4 = [u_prod[:,0],u_prod[:,5]]

datContent = [i.strip().split() for i in open(f"budget/2_turb.m").readlines()]
data = np.array(datContent)
u_turb_diff = data.astype(np.float)
vv_5 = [u_turb_diff[:,0],u_turb_diff[:,5]]

datContent = [i.strip().split() for i in open(f"budget/2_vp.m").readlines()]
data = np.array(datContent)
u_vpgrad = data.astype(np.float)
vv_6 = [u_vpgrad[:,0],u_vpgrad[:,5]]

datContent = [i.strip().split() for i in open(f"budget/3_convection.m").readlines()]
data = np.array(datContent)
u_conv = data.astype(np.float)
ww_1 = [u_conv[:,0],u_conv[:,5]]

datContent = [i.strip().split() for i in open(f"budget/3_diss.m").readlines()]
data = np.array(datContent)
u_diss = data.astype(np.float)
ww_2 = [u_diss[:,0],u_diss[:,5]]

datContent = [i.strip().split() for i in open(f"budget/3_mol_diff.m").readlines()]
data = np.array(datContent)
u_mol_diff = data.astype(np.float)
ww_3 = [u_mol_diff[:,0],u_mol_diff[:,5]]

datContent = [i.strip().split() for i in open(f"budget/3_prod.m").readlines()]
data = np.array(datContent)
u_prod = data.astype(np.float)
ww_4 = [u_prod[:,0],u_prod[:,5]]

datContent = [i.strip().split() for i in open(f"budget/3_turb.m").readlines()]
data = np.array(datContent)
u_turb_diff = data.astype(np.float)
ww_5 = [u_turb_diff[:,0],u_turb_diff[:,5]]

datContent = [i.strip().split() for i in open(f"budget/3_vp.m").readlines()]
data = np.array(datContent)
u_vpgrad = data.astype(np.float)
ww_6 = [u_vpgrad[:,0],u_vpgrad[:,5]]

datContent = [i.strip().split() for i in open(f"budget/4_convection.m").readlines()]
data = np.array(datContent)
u_conv = data.astype(np.float)
uv_1 = [u_conv[:,0],u_conv[:,5]]

datContent = [i.strip().split() for i in open(f"budget/4_diss.m").readlines()]
data = np.array(datContent)
u_diss = data.astype(np.float)
uv_2 = [u_diss[:,0],u_diss[:,5]]

datContent = [i.strip().split() for i in open(f"budget/4_mol_diff.m").readlines()]
data = np.array(datContent)
u_mol_diff = data.astype(np.float)
uv_3 = [u_mol_diff[:,0],u_mol_diff[:,5]]

datContent = [i.strip().split() for i in open(f"budget/4_prod.m").readlines()]
data = np.array(datContent)
u_prod = data.astype(np.float)
uv_4 = [u_prod[:,0],u_prod[:,5]]

datContent = [i.strip().split() for i in open(f"budget/4_turb.m").readlines()]
data = np.array(datContent)
u_turb_diff = data.astype(np.float)
uv_5 = [u_turb_diff[:,0],u_turb_diff[:,5]]

datContent = [i.strip().split() for i in open(f"budget/4_vp.m").readlines()]
data = np.array(datContent)
u_vpgrad = data.astype(np.float)
uv_6 = [u_vpgrad[:,0],u_vpgrad[:,5]]

# %%
datContent = [i.strip().split() for i in open(f"scalar_budget/s1_prod_1.m").readlines()]
data = np.array(datContent)
s1_prod_1 = data.astype(np.float)
s1_1_1 = [s1_prod_1[:,0],s1_prod_1[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s1_thv_diss_1.m").readlines()]
data = np.array(datContent)
s1_diss_1 = data.astype(np.float)
s1_1_2 = [s1_diss_1[:,0],s1_diss_1[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s1_thv_mol_diff_1.m").readlines()]
data = np.array(datContent)
s1_mol_diff_1 = data.astype(np.float)
s1_1_3 = [s1_mol_diff_1[:,0],s1_mol_diff_1[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s1_thp_1.m").readlines()]
data = np.array(datContent)
s1_thp_1 = data.astype(np.float)
s1_1_4 = [s1_thp_1[:,0],s1_thp_1[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s1_thv_turb_diff_1.m").readlines()]
data = np.array(datContent)
s1_turb_diff_1 = data.astype(np.float)
s1_1_5 = [s1_turb_diff_1[:,0],s1_turb_diff_1[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s1_prod_2.m").readlines()]
data = np.array(datContent)
s1_prod_2 = data.astype(np.float)
s1_2_1 = [s1_prod_2[:,0],s1_prod_2[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s1_thv_diss_2.m").readlines()]
data = np.array(datContent)
s1_diss_2 = data.astype(np.float)
s1_2_2 = [s1_diss_2[:,0],s1_diss_2[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s1_thv_mol_diff_2.m").readlines()]
data = np.array(datContent)
s1_mol_diff_2 = data.astype(np.float)
s1_2_3 = [s1_mol_diff_2[:,0],s1_mol_diff_2[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s1_thp_2.m").readlines()]
data = np.array(datContent)
s1_thp_2 = data.astype(np.float)
s1_2_4 = [s1_thp_2[:,0],s1_thp_2[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s1_thv_turb_diff_2.m").readlines()]
data = np.array(datContent)
s1_turb_diff_2 = data.astype(np.float)
s1_2_5 = [s1_turb_diff_2[:,0],s1_turb_diff_2[:,2]]

#########

datContent = [i.strip().split() for i in open(f"scalar_budget/s2_prod_1.m").readlines()]
data = np.array(datContent)
s2_prod_1 = data.astype(np.float)
s2_1_1 = [s2_prod_1[:,0],s2_prod_1[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s2_diss_1.m").readlines()]
data = np.array(datContent)
s2_diss_1 = data.astype(np.float)
s2_1_2 = [s2_diss_1[:,0],s2_diss_1[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s2_mol_diff_1.m").readlines()]
data = np.array(datContent)
s2_mol_diff_1 = data.astype(np.float)
s2_1_3 = [s2_mol_diff_1[:,0],s2_mol_diff_1[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s2_thp_1.m").readlines()]
data = np.array(datContent)
s2_thp_1 = data.astype(np.float)
s2_1_4 = [s2_thp_1[:,0],s2_thp_1[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s2_turb_diff_1.m").readlines()]
data = np.array(datContent)
s2_turb_diff_1 = data.astype(np.float)
s2_1_5 = [s2_turb_diff_1[:,0],s2_turb_diff_1[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s2_prod_2.m").readlines()]
data = np.array(datContent)
s2_prod_2 = data.astype(np.float)
s2_2_1 = [s2_prod_2[:,0],s2_prod_2[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s2_diss_2.m").readlines()]
data = np.array(datContent)
s2_diss_2 = data.astype(np.float)
s2_2_2 = [s2_diss_2[:,0],s2_diss_2[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s2_mol_diff_2.m").readlines()]
data = np.array(datContent)
s2_mol_diff_2 = data.astype(np.float)
s2_2_3 = [s2_mol_diff_2[:,0],s2_mol_diff_2[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s2_thp_2.m").readlines()]
data = np.array(datContent)
s2_thp_2 = data.astype(np.float)
s2_2_4 = [s2_thp_2[:,0],s2_thp_2[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s2_turb_diff_2.m").readlines()]
data = np.array(datContent)
s2_turb_diff_2 = data.astype(np.float)
s2_2_5 = [s2_turb_diff_2[:,0],s2_turb_diff_2[:,2]]

##########
datContent = [i.strip().split() for i in open(f"scalar_budget/s3_prod_1.m").readlines()]
data = np.array(datContent)
s3_prod_1 = data.astype(np.float)
s3_1_1 = [s3_prod_1[:,0],s3_prod_1[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s3_diss_1.m").readlines()]
data = np.array(datContent)
s3_diss_1 = data.astype(np.float)
s3_1_2 = [s3_diss_1[:,0],s3_diss_1[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s3_mol_diff_1.m").readlines()]
data = np.array(datContent)
s3_mol_diff_1 = data.astype(np.float)
s3_1_3 = [s3_mol_diff_1[:,0],s3_mol_diff_1[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s3_thp_1.m").readlines()]
data = np.array(datContent)
s3_thp_1 = data.astype(np.float)
s3_1_4 = [s3_thp_1[:,0],s3_thp_1[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s3_turb_diff_1.m").readlines()]
data = np.array(datContent)
s3_turb_diff_1 = data.astype(np.float)
s3_1_5 = [s3_turb_diff_1[:,0],s3_turb_diff_1[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s3_prod_2.m").readlines()]
data = np.array(datContent)
s3_prod_2 = data.astype(np.float)
s3_2_1 = [s3_prod_2[:,0],s3_prod_2[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s3_diss_2.m").readlines()]
data = np.array(datContent)
s3_diss_2 = data.astype(np.float)
s3_2_2 = [s3_diss_2[:,0],s3_diss_2[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s3_mol_diff_2.m").readlines()]
data = np.array(datContent)
s3_mol_diff_2 = data.astype(np.float)
s3_2_3 = [s3_mol_diff_2[:,0],s3_mol_diff_2[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s3_thp_2.m").readlines()]
data = np.array(datContent)
s3_thp_2 = data.astype(np.float)
s3_2_4 = [s3_thp_2[:,0],s3_thp_2[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s3_turb_diff_2.m").readlines()]
data = np.array(datContent)
s3_turb_diff_2 = data.astype(np.float)
s3_2_5 = [s3_turb_diff_2[:,0],s3_turb_diff_2[:,2]]

########
datContent = [i.strip().split() for i in open(f"scalar_budget/s4_prod_1.m").readlines()]
data = np.array(datContent)
s4_prod_1 = data.astype(np.float)
s4_1_1 = [s4_prod_1[:,0],s4_prod_1[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s4_diss_1.m").readlines()]
data = np.array(datContent)
s4_diss_1 = data.astype(np.float)
s4_1_2 = [s4_diss_1[:,0],s4_diss_1[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s4_mol_diff_1.m").readlines()]
data = np.array(datContent)
s4_mol_diff_1 = data.astype(np.float)
s4_1_3 = [s4_mol_diff_1[:,0],s4_mol_diff_1[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s4_thp_1.m").readlines()]
data = np.array(datContent)
s4_thp_1 = data.astype(np.float)
s4_1_4 = [s4_thp_1[:,0],s4_thp_1[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s4_turb_diff_1.m").readlines()]
data = np.array(datContent)
s4_turb_diff_1 = data.astype(np.float)
s4_1_5 = [s4_turb_diff_1[:,0],s4_turb_diff_1[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s4_prod_2.m").readlines()]
data = np.array(datContent)
s4_prod_2 = data.astype(np.float)
s4_2_1 = [s4_prod_2[:,0],s4_prod_2[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s4_diss_2.m").readlines()]
data = np.array(datContent)
s4_diss_2 = data.astype(np.float)
s4_2_2 = [s4_diss_2[:,0],s4_diss_2[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s4_mol_diff_2.m").readlines()]
data = np.array(datContent)
s4_mol_diff_2 = data.astype(np.float)
s4_2_3 = [s4_mol_diff_2[:,0],s4_mol_diff_2[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s4_thp_2.m").readlines()]
data = np.array(datContent)
s4_thp_2 = data.astype(np.float)
s4_2_4 = [s4_thp_2[:,0],s4_thp_2[:,2]]

datContent = [i.strip().split() for i in open(f"scalar_budget/s4_turb_diff_2.m").readlines()]
data = np.array(datContent)
s4_turb_diff_2 = data.astype(np.float)
s4_2_5 = [s4_turb_diff_2[:,0],s4_turb_diff_2[:,2]]

# %%
compiled = [a,b,c,d,e,f,g,h,ar,br,cr,dr,er,fr,gr,hr,\
           s1,s1i,s2,s2i,s3,s3i,s4,s4i,\
           s1r,s1ir,s2r,s2ir,s3r,s3ir,s4r,s4ir,\
           s1prt,s2prt,s3prt,s4prt,\
           uv,us1,us2,us3,us4,vs1,vs2,vs3,vs4,\
           uskew,vskew,wskew,pskew,uflat,vflat,wflat,pflat,\
           cfx,cfre,redispmom,retau,h12x,h12rt]

compiled_budget = [uu_1,uu_2,uu_3,uu_4,uu_5,uu_6,\
                   vv_1,vv_2,vv_3,vv_4,vv_5,vv_6,\
                   ww_1,ww_2,ww_3,ww_4,ww_5,ww_6,\
                   uv_1,uv_2,uv_3,uv_4,uv_5,uv_6]

compiled_scalar_budget = [s1_1_1,s1_1_2,s1_1_3,s1_1_4,s1_1_5,\
                          s1_2_1,s1_2_2,s1_2_3,s1_2_4,s1_2_5,\
                          s2_1_1,s2_1_2,s2_1_3,s2_1_4,s2_1_5,\
                          s2_2_1,s2_2_2,s2_2_3,s2_2_4,s2_2_5,\
                          s3_1_1,s3_1_2,s3_1_3,s3_1_4,s3_1_5,\
                          s3_2_1,s3_2_2,s3_2_3,s3_2_4,s3_2_5,\
                          s4_1_1,s4_1_2,s4_1_3,s4_1_4,s4_1_5,\
                          s4_2_1,s4_2_2,s4_2_3,s4_2_4,s4_2_5]

# %%
class my_dictionary(dict): 
    def __init__(self): 
        self = dict()
    def add(self, key, value): 
        self[key] = value 

dataset = my_dictionary()

# %%
quant = 'flow'
ftype = 'tbl'
datype = ['mean','rms']
var = ['u','v','w','p']
typ = ['outer','inner']
x = ['420','628','830','1070']

z = 0
for k in range(len(datype)):
    for j in range(len(var)):
        for i in range(len(typ)):
            for n in range(len(x)):
                dataset.key = f'{quant}_{ftype}_{x[n]}_{datype[k]}_{var[j]}_{typ[i]}'
                dataset.value = (compiled[z][:,0],compiled[z][:,n+1])
                dataset.add(dataset.key, dataset.value)
            z+=1
            
quant = 'scalar'
ftype = 'tbl'
datype = ['mean','rms']
var = ['s1','s2','s3','s4']
typ = ['outer','inner']
x = ['420','628','830','1070']

for k in range(len(datype)):
    for j in range(len(var)):
        for i in range(len(typ)):
            for n in range(len(x)):
                dataset.key = f'{quant}_{ftype}_{x[n]}_{datype[k]}_{var[j]}_{typ[i]}'
                dataset.value = (compiled[z][:,0],compiled[z][:,n+1])
                dataset.add(dataset.key, dataset.value)
            z+=1
            
quant = 'scalar'
ftype = 'tbl'
datype = ['Prt']
var = ['s1','s2','s3','s4']
typ = ['inner']
x = ['420','628','830','1070']

for k in range(len(datype)):
    for j in range(len(var)):
        for i in range(len(typ)):
            for n in range(len(x)):
                dataset.key = f'{quant}_{ftype}_{x[n]}_{datype[k]}_{var[j]}_{typ[i]}'
                dataset.value = (compiled[z][:,0],compiled[z][:,n+1])
                dataset.add(dataset.key, dataset.value)
            z+=1

quant = 'flow'
ftype = 'tbl'
datype = 'shear'
var = 'uv'
typ = 'inner'
x = ['420','628','830','1070']

for n in range(len(x)):
    dataset.key = f'{quant}_{ftype}_{x[n]}_{datype}_{var}_{typ}'
    dataset.value = (compiled[z][:,0],compiled[z][:,n+1])
    dataset.add(dataset.key, dataset.value)
z+=1
            
quant = 'scalar'
ftype = 'tbl'
datype = ['flux']
var = ['us1','us2','us3','us4']
typ = ['inner']
x = ['420','628','830','1070']

for k in range(len(datype)):
    for j in range(len(var)):
        for i in range(len(typ)):
            for n in range(len(x)):
                dataset.key = f'{quant}_{ftype}_{x[n]}_{datype[k]}_{var[j]}_{typ[i]}'
                dataset.value = (compiled[z][:,0],compiled[z][:,n+1])
                dataset.add(dataset.key, dataset.value)
            z+=1
            
quant = 'scalar'
ftype = 'tbl'
datype = ['flux']
var = ['vs1','vs2','vs3','vs4']
typ = ['inner']
x = ['420','628','830','1070']

for k in range(len(datype)):
    for j in range(len(var)):
        for i in range(len(typ)):
            for n in range(len(x)):
                dataset.key = f'{quant}_{ftype}_{x[n]}_{datype[k]}_{var[j]}_{typ[i]}'
                dataset.value = (compiled[z][:,0],compiled[z][:,n+1])
                dataset.add(dataset.key, dataset.value)
            z+=1
            
quant = 'flow'
ftype = 'tbl'
datype = ['skewness']
var = ['u','v','w','p']
typ = ['inner']
x = ['420','628','830','1070']

for k in range(len(datype)):
    for j in range(len(var)):
        for i in range(len(typ)):
            for n in range(len(x)):
                dataset.key = f'{quant}_{ftype}_{x[n]}_{datype[k]}_{var[j]}_{typ[i]}'
                dataset.value = (compiled[z][:,0],compiled[z][:,n+1])
                dataset.add(dataset.key, dataset.value)
            z+=1
            
quant = 'flow'
ftype = 'tbl'
datype = ['flatness']
var = ['u','v','w','p']
typ = ['inner']
x = ['420','628','830','1070']

for k in range(len(datype)):
    for j in range(len(var)):
        for i in range(len(typ)):
            for n in range(len(x)):
                dataset.key = f'{quant}_{ftype}_{x[n]}_{datype[k]}_{var[j]}_{typ[i]}'
                dataset.value = (compiled[z][:,0],compiled[z][:,n+1])
                dataset.add(dataset.key, dataset.value)
            z+=1
             
quant = 'flow'
ftype = 'tbl'
datype = 'mean_params'
var = 'cf_wrt_x'

dataset.key = f'{quant}_{ftype}_{datype}_{var}'
dataset.value = (compiled[z][:,0],compiled[z][:,1])
dataset.add(dataset.key, dataset.value)
z+=1

quant = 'flow'
ftype = 'tbl'
datype = 'mean_params'
var = 'cf_wrt_Rex'

dataset.key = f'{quant}_{ftype}_{datype}_{var}'
dataset.value = (compiled[z][:,0],compiled[z][:,1])
dataset.add(dataset.key, dataset.value)
z+=1

quant = 'flow'
ftype = 'tbl'
datype = 'mean_params'
var = 'Redisp_wrt_x'

dataset.key = f'{quant}_{ftype}_{datype}_{var}'
dataset.value = (compiled[z][:,0],compiled[z][:,1])
dataset.add(dataset.key, dataset.value)

quant = 'flow'
ftype = 'tbl'
datype = 'mean_params'
var = 'Retheta_wrt_x'

dataset.key = f'{quant}_{ftype}_{datype}_{var}'
dataset.value = (compiled[z][:,0],compiled[z][:,2])
dataset.add(dataset.key, dataset.value)
z+=1

quant = 'flow'
ftype = 'tbl'
datype = 'mean_params'
var = 'Retau_wrt_x'

dataset.key = f'{quant}_{ftype}_{datype}_{var}'
dataset.value = (compiled[z][:,0],compiled[z][:,1])
dataset.add(dataset.key, dataset.value)
z+=1

quant = 'flow'
ftype = 'tbl'
datype = 'mean_params'
var = 'h12_wrt_x'

dataset.key = f'{quant}_{ftype}_{datype}_{var}'
dataset.value = (compiled[z][:,0],compiled[z][:,1])
dataset.add(dataset.key, dataset.value)
z+=1

quant = 'flow'
ftype = 'tbl'
datype = 'mean_params'
var = 'h12_wrt_Retheta'

dataset.key = f'{quant}_{ftype}_{datype}_{var}'
dataset.value = (compiled[z][:,0],compiled[z][:,1])
dataset.add(dataset.key, dataset.value)
z+=1

# %%
quant = 'flow'
ftype = 'tbl'
datype = ['uu_budget','vv_budget','ww_budget','uv_budget']
var = ['convection','dissipation','molecular_diffusion','production','turb_diffusion','vpgrad']
typ = 'inner'
x = '1070'

z = 0
for k in range(len(datype)):
    for j in range(len(var)):
        dataset.key = f'{quant}_{ftype}_{x}_{datype[k]}_{var[j]}_{typ}'
        dataset.value = (compiled_budget[z][0],compiled_budget[z][1])
        dataset.add(dataset.key, dataset.value)
    z+=1
    
quant = 'scalar'
ftype = 'tbl'
datype = ['us1_budget','vs1_budget','us2_budget','vs2_budget','us3_budget','vs3_budget','us4_budget','vs4_budget']
var = ['production','dissipation','molecular_diffusion','theta-p','turb_diffusion']
typ = 'inner'
x = '1070'

z = 0
for k in range(len(datype)):
    for j in range(len(var)):
        dataset.key = f'{quant}_{ftype}_{x}_{datype[k]}_{var[j]}_{typ}'
        dataset.value = (compiled_scalar_budget[z][0],compiled_scalar_budget[z][1])
        dataset.add(dataset.key, dataset.value)
    z+=1

# %%
for i in dataset.keys():
    print(i)
# Out:
# flow_tbl_420_mean_u_outer
# flow_tbl_628_mean_u_outer
# flow_tbl_830_mean_u_outer
# flow_tbl_1070_mean_u_outer
# flow_tbl_420_mean_u_inner
# flow_tbl_628_mean_u_inner
# flow_tbl_830_mean_u_inner
# flow_tbl_1070_mean_u_inner
# flow_tbl_420_mean_v_outer
# flow_tbl_628_mean_v_outer
# flow_tbl_830_mean_v_outer
# flow_tbl_1070_mean_v_outer
# flow_tbl_420_mean_v_inner
# flow_tbl_628_mean_v_inner
# flow_tbl_830_mean_v_inner
# flow_tbl_1070_mean_v_inner
# flow_tbl_420_mean_w_outer
# flow_tbl_628_mean_w_outer
# flow_tbl_830_mean_w_outer
# flow_tbl_1070_mean_w_outer
# flow_tbl_420_mean_w_inner
# flow_tbl_628_mean_w_inner
# flow_tbl_830_mean_w_inner
# flow_tbl_1070_mean_w_inner
# flow_tbl_420_mean_p_outer
# flow_tbl_628_mean_p_outer
# flow_tbl_830_mean_p_outer
# flow_tbl_1070_mean_p_outer
# flow_tbl_420_mean_p_inner
# flow_tbl_628_mean_p_inner
# flow_tbl_830_mean_p_inner
# flow_tbl_1070_mean_p_inner
# flow_tbl_420_rms_u_outer
# flow_tbl_628_rms_u_outer
# flow_tbl_830_rms_u_outer
# ...

# %%
test = dataset['flow_tbl_628_rms_v_inner']
plt.plot(test[0],test[1])

# %%
np.savez('TBL_statistics.npz',**dataset)
